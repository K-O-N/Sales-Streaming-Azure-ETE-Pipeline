# %%
datasets = [ 
    {"file_name": "Address"},
    {"file_name": "Customer"},
    {"file_name": "CustomerAddress"},
    {"file_name": "Product"},
    {"file_name": "ProductCategory"},
    {"file_name": "ProductDescription"},
    {"file_name": "ProductModel"},
    {"file_name": "SalesOrderDetail"},
    {"file_name": "SalesOrderHeader"}
     
]

# %%
dbutils.jobs.taskValues.set("output_dataset", datasets)
